# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

import wandb

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Network error (ConnectionError), entering retry loop.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()
project = 'seanxx/11711-hw4-ablation'
runs = api.runs(project)
# Out:
# wandb: Network error (ConnectionError), entering retry loop.

# %%
results = []
for run in tqdm(runs):
    if 'pre' in run.tags:
        continue

    config = run.config
    summary = run.summary

    result = {}
    result['id'] = run.id
    result['embedding_path'] = config.get('embedding_path', None)
    result['test_roc_auc'] = summary.get('test_roc_auc', None)
    result['test_pr_auc'] = summary.get('test_pr_auc', None)

    results.append(result)

df = pd.DataFrame(results)
df
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 17382.91it/s]
#           id                                     embedding_path  test_roc_auc  \
# 0   2xolxt98                       embeddings/icd2embedding.pkl      0.701144
# 1   vjyekhzh                       embeddings/icd2embedding.pkl      0.707695
# 2   ukb9y84o  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.632297
# 3   hr0mo15f  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.629821
# 4   n3os4rwn                       embeddings/icd2embedding.pkl      0.701622
# 5   vgnjbae2                       embeddings/icd2embedding.pkl      0.698680
# 6   dxv3rb1o                       embeddings/icd2embedding.pkl      0.699645
# 7   eqo7pgm3  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.636358
# 8   pa4i8kx9                       embeddings/icd2embedding.pkl      0.705070
# 9   mgm3v8r1                       embeddings/icd2embedding.pkl      0.703136
# 10  qj7zqjd6  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.632133
# 11  hdxi3vut                       embeddings/icd2embedding.pkl      0.706354
# 12  3j7s8pwm                       embeddings/icd2embedding.pkl      0.694518
# 13  3q07n7ru                       embeddings/icd2embedding.pkl      0.703274
# 14  yynk9lxe                       embeddings/icd2embedding.pkl      0.706323
# 15  pbbddpii                       embeddings/icd2embedding.pkl      0.695188
# 16  9sccsjzv  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.638431
# 17  8xehm34s                       embeddings/icd2embedding.pkl      0.700205
# 18  sdxvubj0                       embeddings/icd2embedding.pkl      0.700149
# 19  uy05t3j4                       embeddings/icd2embedding.pkl      0.648090
# 20  3t5eo91p                       embeddings/icd2embedding.pkl      0.700544
# 21  5zynuhry  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.635158
# 22  9h5zjojt                       embeddings/icd2embedding.pkl      0.708851
# 23  yz8rbhhk  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.629339
# 24  blp9wp7r                       embeddings/icd2embedding.pkl      0.709178
# 25  me7ghllx                       embeddings/icd2embedding.pkl      0.705537
# 26  wd87gz9x                       embeddings/icd2embedding.pkl      0.708593
# 27  kiz7ll7x                       embeddings/icd2embedding.pkl      0.710070
# 28  1guyvbi8  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.636551
# 29  06tw6stt                       embeddings/icd2embedding.pkl      0.710231
# 30  cyynd8ha                       embeddings/icd2embedding.pkl      0.698716
# 31  t0fu0mxy                       embeddings/icd2embedding.pkl      0.700855
# 32  q3oupxr0                       embeddings/icd2embedding.pkl      0.706432
# 33  36ce4x0h                       embeddings/icd2embedding.pkl      0.712469
# 34  590ednxx  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.638268
# 35  ykpathti                       embeddings/icd2embedding.pkl      0.696545
# 36  iys8871k  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.635985
# 37  862age1j                       embeddings/icd2embedding.pkl      0.709756
# 38  1uw4obqz                       embeddings/icd2embedding.pkl      0.708771
# 39  f2308jlz                       embeddings/icd2embedding.pkl      0.703488
# 40  2mcstwab                       embeddings/icd2embedding.pkl      0.699628
# 41  ufdl88es  embeddings/Bio_ClinicalBERT_sentence2embedding...      0.634310
# 42  c7spghwu                       embeddings/icd2embedding.pkl      0.704444
# 43  iqzgfwbt                       embeddings/icd2embedding.pkl      0.699367
#
#     test_pr_auc
# 0      0.740610
# 1      0.751325
# 2      0.682577
# 3      0.679815
# 4      0.739252
# 5      0.741078
# 6      0.738816
# 7      0.686731
# 8      0.741387
# 9      0.741615
# 10     0.689534
# 11     0.743602
# 12     0.739228
# 13     0.748227
# 14     0.742094
# 15     0.732980
# 16     0.684645
# 17     0.745565
# 18     0.738481
# 19     0.685626
# 20     0.739919
# 21     0.682098
# 22     0.751474
# 23     0.682178
# 24     0.746813
# 25     0.750515
# 26     0.740777
# 27     0.757294
# 28     0.691248
# 29     0.752626
# 30     0.741600
# 31     0.744363
# 32     0.753378
# 33     0.751408
# 34     0.688999
# 35     0.736730
# 36     0.685288
# 37     0.747264
# 38     0.748943
# 39     0.744938
# 40     0.737249
# 41     0.678660
# 42     0.743757
# 43     0.742603

# %%
hue_col = 'Protocol Embedding Model'
df[hue_col] = df['embedding_path'].apply(
    lambda x: 'OpenAI text-embedding-3-large' if 'icd2embedding' in x else 'ClinicalBERT')

# %%
figsize = (8.5, 5)

# %%
title_size = 20
label_size = 16

# %%
plt.figure(figsize=figsize)

sns.scatterplot(data=df, s=60, x='test_roc_auc', y='test_pr_auc', hue=hue_col,
                palette=['red', "gray"])

# plt.title('Scatter Plot of Ablation Experiment Performance', fontsize=title_size)
plt.xlabel('Test ROC-AUC', fontsize=label_size)
plt.ylabel('Test PR-AUC', fontsize=label_size)
plt.legend(loc='upper left', fontsize=label_size, title=hue_col, title_fontsize=label_size)
plt.xticks(np.linspace(0.62, 0.72, 21), rotation=45)
plt.yticks(np.linspace(0.67, 0.77, 11), rotation=0)
plt.grid(True, linestyle='--')
plt.gca().set_axisbelow(True)

plt.tight_layout()
plt.savefig('scatter_plot.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=figsize)

best_model_ids = ['36ce4x0h', 'kiz7ll7x']
model_name = ['GHINT-v1', 'GHINT-v2']
colors = ['tab:blue', 'tab:orange']

for i, model_id in enumerate(best_model_ids):
    run = api.run(os.path.join(project, model_id))
    hist_df = run.history().iloc[:-1, :]
    hist_df['Epoch'] = hist_df['_step'] + 1
    plt.plot(hist_df['Epoch'], hist_df['train_loss'],
             label=f'{model_name[i]} Train Loss', color=colors[i])
    plt.plot(hist_df['Epoch'], hist_df['val_loss'], linestyle='dashed',
             label=f'{model_name[i]} Validation Loss', color=colors[i])

# plt.title('Loss Curves of 2 Best Models', fontsize=title_size)
plt.xlabel('Epoch', fontsize=label_size)
plt.ylabel('Loss', fontsize=label_size)
plt.legend(fontsize=13)
plt.grid(True, linestyle='--')
plt.gca().set_axisbelow(True)

plt.tight_layout()
plt.savefig('loss_plot.png', dpi=300)
plt.show()
